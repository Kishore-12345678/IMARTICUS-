# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df=pd.read_csv("Mobiles Dataset (2025).csv")

# %%
df
# Out:
#     Company Name            Model Name Mobile Weight   RAM     Front Camera  \
# 0          Apple       iPhone 16 128GB          174g   6GB             12MP
# 1          Apple       iPhone 16 256GB          174g   6GB             12MP
# 2          Apple       iPhone 16 512GB          174g   6GB             12MP
# 3          Apple  iPhone 16 Plus 128GB          203g   6GB             12MP
# 4          Apple  iPhone 16 Plus 256GB          203g   6GB             12MP
# ..           ...                   ...           ...   ...              ...
# 925         Poco          Pad 5G 128GB          571g   8GB              8MP
# 926         Poco          Pad 5G 256GB          571g   8GB              8MP
# 927      Samsung  Galaxy Z Fold6 256GB          239g  12GB  10MP, 4MP (UDC)
# 928      Samsung  Galaxy Z Fold6 512GB          239g  12GB  10MP, 4MP (UDC)
# 929      Samsung    Galaxy Z Fold6 1TB          239g  12GB  10MP, 4MP (UDC)
#
# ...

# %%
df.head(5)
# Out:
#   Company Name            Model Name Mobile Weight  RAM Front Camera  \
# 0        Apple       iPhone 16 128GB          174g  6GB         12MP
# 1        Apple       iPhone 16 256GB          174g  6GB         12MP
# 2        Apple       iPhone 16 512GB          174g  6GB         12MP
# 3        Apple  iPhone 16 Plus 128GB          203g  6GB         12MP
# 4        Apple  iPhone 16 Plus 256GB          203g  6GB         12MP
#
#   Back Camera   Processor Battery Capacity Screen Size  \
# 0        48MP  A17 Bionic         3,600mAh  6.1 inches
# 1        48MP  A17 Bionic         3,600mAh  6.1 inches
# 2        48MP  A17 Bionic         3,600mAh  6.1 inches
# 3        48MP  A17 Bionic         4,200mAh  6.7 inches
# 4        48MP  A17 Bionic         4,200mAh  6.7 inches
#
#   Launched Price (Pakistan) Launched Price (India) Launched Price (China)  \
# 0               PKR 224,999             INR 79,999              CNY 5,799
# ...

# %%
df.shape
# Out:
# (930, 15)

# %%
df[df.duplicated()]
# Out:
#     Company Name        Model Name Mobile Weight   RAM Front Camera  \
# 347         Oppo          A3 128GB          186g   4GB          5MP
# 437         Oppo        K11x 128GB          195g   8GB         16MP
# 438         Oppo        K11x 256GB          195g  12GB         16MP
# 441         Oppo        K10x 128GB          195g   6GB         16MP
# 442         Oppo        K10x 256GB          195g   8GB         16MP
# 443         Oppo      K10 5G 128GB          205g   8GB         16MP
# 445         Oppo         K9x 128GB          194g   6GB         16MP
# 446         Oppo         K9x 256GB          194g   8GB         16MP
# 447         Oppo   K9 Pro 5G 128GB          180g   8GB         16MP
# 448         Oppo   K9 Pro 5G 256GB          180g  12GB         16MP
# 449         Oppo       K9 5G 128GB          172g   8GB         32MP
# 450         Oppo       K9 5G 256GB          172g   8GB         32MP
# 451         Oppo         K7x 128GB          194g   6GB         16MP
# ...

# %%
df.drop_duplicates(keep='first',inplace=True)

# %%
df.shape
# Out:
# (915, 15)

# %%
df.isnull().sum()
# Out:
# Company Name                 0
# Model Name                   0
# Mobile Weight                0
# RAM                          0
# Front Camera                 0
# Back Camera                  0
# Processor                    0
# Battery Capacity             0
# Screen Size                  0
# Launched Price (Pakistan)    0
# Launched Price (India)       0
# Launched Price (China)       0
# Launched Price (USA)         0
# Launched Price (Dubai)       0
# Launched Year                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Company Name', 'Model Name', 'Mobile Weight', 'RAM', 'Front Camera',
#        'Back Camera', 'Processor', 'Battery Capacity', 'Screen Size',
#        'Launched Price (Pakistan)', 'Launched Price (India)',
#        'Launched Price (China)', 'Launched Price (USA)',
#        'Launched Price (Dubai)', 'Launched Year'],
#       dtype='object')

# %%
sns.countplot(data=df, x='RAM')
plt.title('Mobile Processors')
plt.show()

# %%
sns.boxplot(data=df, x='RAM', y='Launched Price (India)')
plt.title('Price Distribution by Processor')
plt.show()

# %%
df['RAM'].unique()
# Out:
# array(['6GB', '8GB', '4GB', '3GB', '12GB', '2GB', '1.5GB', '16GB', '10GB',
#        '1GB', '8GB / 12GB'], dtype=object)

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='RAM', hue='Launched Price (India)', data=df)
plt.xticks(rotation=45)
plt.title('Price Range per Processor Type')
# Out:
# Text(0.5, 1.0, 'Price Range per Processor Type')

# %%
from sklearn.preprocessing import LabelEncoder

# Make a copy to keep original data safe
df_encoded = df.copy()

# Initialize LabelEncoder
le = LabelEncoder()

# Convert processor column from strings to numbers
df_encoded['RAM'] = le.fit_transform(df_encoded['RAM'])

# Now it's safe to use in ML models or numerical analysis
print(df_encoded[['RAM', 'Launched Price (India)']].head())
# Out:
#    RAM Launched Price (India)
# 0    8             INR 79,999
# 1    8             INR 84,999
# 2    8             INR 89,999
# 3    8             INR 89,999
# 4    8             INR 94,999

# %%
sns.pairplot(data=df)
